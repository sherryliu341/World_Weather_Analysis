# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the Latitude and Longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 757

# %%
# Import the request library.
import requests

from datetime import datetime
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# List of city data.
city_data = []

# Print to logger.
print('Beginning Data Retrieval')
print('-' * 25)

# Create a counter.
record_count = 1
set_count = 1
for index, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = f"{url}&q={city.replace(' ', '+')}"
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
        try:
            city_rain_inches = city_weather['rain']['1h']
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather['snow']['1h']
        except KeyError:
            city_snow_inches = 0
            
        # Append the city information into city_data.
        city_data.append(
        {
            'City': city,
            'Lat': city_lat,
            'Lng': city_lng,
            'Max Temp': city_max_temp,
            'Current Description': city_weather_description,
            'Rain (inches)': city_rain_inches,
            'Snow (inches)': city_snow_inches,
            'Humidity': city_humidity,
            'Cloudiness': city_clouds,
            'Wind Speed': city_wind,
            'Country': city_country
        })
    except:
        print('City not found. Skipping...')
        pass
# Indicate that the Data Loading is complete.
print('-' * 20)
print('Data Retrieval Complete')
print('-' * 20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | douglas
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | constitucion
# Processing Record 8 of Set 1 | souillac
# Processing Record 9 of Set 1 | sechura
# Processing Record 10 of Set 1 | saint george
# Processing Record 11 of Set 1 | alofi
# Processing Record 12 of Set 1 | moron
# Processing Record 13 of Set 1 | chuy
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | russell
# Processing Record 16 of Set 1 | provideniya
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | pula
# Processing Record 19 of Set 1 | karmala
# Processing Record 20 of Set 1 | bubaque
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | talnakh
# Processing Record 23 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | tillabery
# City not found. Skipping...
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | nikolskoye
# Processing Record 28 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 1 | hengshui
# Processing Record 30 of Set 1 | surt
# Processing Record 31 of Set 1 | quatre cocos
# Processing Record 32 of Set 1 | cherskiy
# Processing Record 33 of Set 1 | avera
# Processing Record 34 of Set 1 | khatanga
# Processing Record 35 of Set 1 | vila franca do campo
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | komyshuvakha
# Processing Record 39 of Set 1 | boyle
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | stokmarknes
# Processing Record 42 of Set 1 | nuuk
# Processing Record 43 of Set 1 | santa comba
# Processing Record 44 of Set 1 | portland
# Processing Record 45 of Set 1 | praia da vitoria
# Processing Record 46 of Set 1 | bethel
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | narsaq
# Processing Record 49 of Set 1 | pevek
# Processing Record 50 of Set 1 | castro
# Processing Record 1 of Set 2 | hohhot
# Processing Record 2 of Set 2 | payyannur
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | victoria
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | saskylakh
# Processing Record 8 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 2 | cacoal
# Processing Record 10 of Set 2 | eenhana
# Processing Record 11 of Set 2 | antakya
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | comodoro rivadavia
# Processing Record 14 of Set 2 | san patricio
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 2 | arraial do cabo
# Processing Record 18 of Set 2 | amapa
# Processing Record 19 of Set 2 | amazar
# Processing Record 20 of Set 2 | port hedland
# Processing Record 21 of Set 2 | bhikangaon
# Processing Record 22 of Set 2 | belaya kholunitsa
# Processing Record 23 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 24 of Set 2 | hambantota
# Processing Record 25 of Set 2 | la ronge
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | hobart
# Processing Record 28 of Set 2 | tomatlan
# Processing Record 29 of Set 2 | halifax
# Processing Record 30 of Set 2 | atuona
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | lorengau
# Processing Record 34 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 2 | onega
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | leeton
# Processing Record 38 of Set 2 | san andres
# Processing Record 39 of Set 2 | touros
# Processing Record 40 of Set 2 | kahului
# Processing Record 41 of Set 2 | fortuna
# Processing Record 42 of Set 2 | pyu
# Processing Record 43 of Set 2 | port hawkesbury
# Processing Record 44 of Set 2 | kimberley
# Processing Record 45 of Set 2 | hami
# Processing Record 46 of Set 2 | cabedelo
# Processing Record 47 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 2 | cidreira
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | chokurdakh
# Processing Record 1 of Set 3 | bluff
# Processing Record 2 of Set 3 | litovko
# Processing Record 3 of Set 3 | tura
# Processing Record 4 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 3 | aasiaat
# Processing Record 6 of Set 3 | hanyang
# Processing Record 7 of Set 3 | kigoma
# Processing Record 8 of Set 3 | ponta do sol
# Processing Record 9 of Set 3 | cape town
# Processing Record 10 of Set 3 | timbiqui
# Processing Record 11 of Set 3 | ancud
# Processing Record 12 of Set 3 | haines junction
# Processing Record 13 of Set 3 | pili
# Processing Record 14 of Set 3 | butaritari
# Processing Record 15 of Set 3 | neiafu
# Processing Record 16 of Set 3 | lebu
# Processing Record 17 of Set 3 | paysandu
# Processing Record 18 of Set 3 | san-pedro
# Processing Record 19 of Set 3 | khor
# Processing Record 20 of Set 3 | coralville
# Processing Record 21 of Set 3 | mecca
# Processing Record 22 of Set 3 | tiksi
# Processing Record 23 of Set 3 | charters towers
# Processing Record 24 of Set 3 | casper
# Processing Record 25 of Set 3 | strezhevoy
# Processing Record 26 of Set 3 | rio gallegos
# Processing Record 27 of Set 3 | qaanaaq
# Processing Record 28 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 3 | tocopilla
# Processing Record 30 of Set 3 | banda aceh
# Processing Record 31 of Set 3 | sumbe
# Processing Record 32 of Set 3 | turayf
# Processing Record 33 of Set 3 | riyadh
# Processing Record 34 of Set 3 | banswara
# Processing Record 35 of Set 3 | longyearbyen
# Processing Record 36 of Set 3 | kamaishi
# Processing Record 37 of Set 3 | biak
# Processing Record 38 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 3 | tsabong
# Processing Record 40 of Set 3 | kachiry
# Processing Record 41 of Set 3 | mogadishu
# Processing Record 42 of Set 3 | derzhavinsk
# Processing Record 43 of Set 3 | petatlan
# Processing Record 44 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 3 | fairbanks
# Processing Record 46 of Set 3 | usakos
# Processing Record 47 of Set 3 | sulina
# Processing Record 48 of Set 3 | mizan teferi
# Processing Record 49 of Set 3 | odweyne
# Processing Record 50 of Set 3 | jalu
# Processing Record 1 of Set 4 | mahebourg
# Processing Record 2 of Set 4 | viedma
# Processing Record 3 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 4 | ahipara
# Processing Record 5 of Set 4 | prince rupert
# Processing Record 6 of Set 4 | hasaki
# Processing Record 7 of Set 4 | mar del plata
# Processing Record 8 of Set 4 | muros
# Processing Record 9 of Set 4 | hay river
# Processing Record 10 of Set 4 | nemuro
# Processing Record 11 of Set 4 | pangnirtung
# Processing Record 12 of Set 4 | geraldton
# Processing Record 13 of Set 4 | faanui
# Processing Record 14 of Set 4 | santiago del estero
# Processing Record 15 of Set 4 | upernavik
# Processing Record 16 of Set 4 | deputatskiy
# Processing Record 17 of Set 4 | palmer
# Processing Record 18 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 4 | barrow
# Processing Record 20 of Set 4 | dikson
# Processing Record 21 of Set 4 | srednekolymsk
# Processing Record 22 of Set 4 | luwuk
# Processing Record 23 of Set 4 | iqaluit
# Processing Record 24 of Set 4 | dargaville
# Processing Record 25 of Set 4 | xiashi
# Processing Record 26 of Set 4 | yasnyy
# Processing Record 27 of Set 4 | tombouctou
# Processing Record 28 of Set 4 | thiruvananthapuram
# Processing Record 29 of Set 4 | cururupu
# Processing Record 30 of Set 4 | oranjemund
# Processing Record 31 of Set 4 | gravdal
# Processing Record 32 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 4 | cabo san lucas
# Processing Record 34 of Set 4 | husavik
# Processing Record 35 of Set 4 | kavieng
# Processing Record 36 of Set 4 | new norfolk
# Processing Record 37 of Set 4 | kulhudhuffushi
# Processing Record 38 of Set 4 | yulara
# Processing Record 39 of Set 4 | severo-kurilsk
# Processing Record 40 of Set 4 | wenling
# Processing Record 41 of Set 4 | arvin
# Processing Record 42 of Set 4 | richards bay
# Processing Record 43 of Set 4 | mitu
# Processing Record 44 of Set 4 | rundu
# Processing Record 45 of Set 4 | hithadhoo
# Processing Record 46 of Set 4 | den helder
# Processing Record 47 of Set 4 | nanortalik
# Processing Record 48 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 4 | careiro da varzea
# Processing Record 50 of Set 4 | ostersund
# Processing Record 1 of Set 5 | erdenet
# Processing Record 2 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 5 | coahuayana
# Processing Record 4 of Set 5 | kanigoro
# Processing Record 5 of Set 5 | yelizovo
# Processing Record 6 of Set 5 | bobo dioulasso
# Processing Record 7 of Set 5 | avarua
# Processing Record 8 of Set 5 | isangel
# Processing Record 9 of Set 5 | torbay
# Processing Record 10 of Set 5 | bonavista
# Processing Record 11 of Set 5 | lamont
# Processing Record 12 of Set 5 | gisborne
# Processing Record 13 of Set 5 | kununurra
# Processing Record 14 of Set 5 | harlingen
# Processing Record 15 of Set 5 | languyan
# Processing Record 16 of Set 5 | houma
# Processing Record 17 of Set 5 | maloy
# Processing Record 18 of Set 5 | coquimbo
# Processing Record 19 of Set 5 | teya
# Processing Record 20 of Set 5 | huarmey
# Processing Record 21 of Set 5 | mbigou
# Processing Record 22 of Set 5 | evensk
# Processing Record 23 of Set 5 | lata
# Processing Record 24 of Set 5 | samokov
# Processing Record 25 of Set 5 | camopi
# Processing Record 26 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 5 | kalemie
# Processing Record 28 of Set 5 | northam
# Processing Record 29 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 5 | siniscola
# Processing Record 31 of Set 5 | chitral
# Processing Record 32 of Set 5 | balyaga
# Processing Record 33 of Set 5 | zhigansk
# Processing Record 34 of Set 5 | honiara
# Processing Record 35 of Set 5 | ichchapuram
# Processing Record 36 of Set 5 | westlock
# Processing Record 37 of Set 5 | sakakah
# Processing Record 38 of Set 5 | bilbor
# Processing Record 39 of Set 5 | umm kaddadah
# Processing Record 40 of Set 5 | hamilton
# Processing Record 41 of Set 5 | kayerkan
# Processing Record 42 of Set 5 | yar-sale
# Processing Record 43 of Set 5 | anadyr
# Processing Record 44 of Set 5 | luau
# Processing Record 45 of Set 5 | sitka
# Processing Record 46 of Set 5 | qurayyat
# Processing Record 47 of Set 5 | shimoda
# Processing Record 48 of Set 5 | bobrovka
# Processing Record 49 of Set 5 | zunyi
# Processing Record 50 of Set 5 | polur
# Processing Record 1 of Set 6 | santa maria
# Processing Record 2 of Set 6 | sioux lookout
# Processing Record 3 of Set 6 | homer
# Processing Record 4 of Set 6 | sao filipe
# Processing Record 5 of Set 6 | lavrentiya
# Processing Record 6 of Set 6 | aloleng
# Processing Record 7 of Set 6 | pundaguitan
# Processing Record 8 of Set 6 | kushmurun
# Processing Record 9 of Set 6 | saint-pierre
# Processing Record 10 of Set 6 | namibe
# Processing Record 11 of Set 6 | igarka
# Processing Record 12 of Set 6 | carnarvon
# Processing Record 13 of Set 6 | las cruces
# Processing Record 14 of Set 6 | namatanai
# Processing Record 15 of Set 6 | rocky mountain house
# Processing Record 16 of Set 6 | razdolnoye
# Processing Record 17 of Set 6 | bambanglipuro
# Processing Record 18 of Set 6 | voh
# Processing Record 19 of Set 6 | ati
# Processing Record 20 of Set 6 | upington
# Processing Record 21 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 22 of Set 6 | aksay
# Processing Record 23 of Set 6 | adjumani
# Processing Record 24 of Set 6 | mercedes
# Processing Record 25 of Set 6 | komsomolskiy
# Processing Record 26 of Set 6 | nome
# Processing Record 27 of Set 6 | yongzhou
# Processing Record 28 of Set 6 | leningradskiy
# Processing Record 29 of Set 6 | pouebo
# Processing Record 30 of Set 6 | vigrestad
# Processing Record 31 of Set 6 | norheimsund
# Processing Record 32 of Set 6 | bayan
# Processing Record 33 of Set 6 | gashua
# Processing Record 34 of Set 6 | xicotencatl
# Processing Record 35 of Set 6 | nha trang
# Processing Record 36 of Set 6 | esperance
# Processing Record 37 of Set 6 | miri
# Processing Record 38 of Set 6 | bograd
# Processing Record 39 of Set 6 | soldotna
# Processing Record 40 of Set 6 | chiang klang
# Processing Record 41 of Set 6 | ukiah
# Processing Record 42 of Set 6 | kutum
# Processing Record 43 of Set 6 | leninskoye
# Processing Record 44 of Set 6 | bambous virieux
# Processing Record 45 of Set 6 | sur
# Processing Record 46 of Set 6 | coihaique
# Processing Record 47 of Set 6 | egvekinot
# Processing Record 48 of Set 6 | koutiala
# Processing Record 49 of Set 6 | san jose
# Processing Record 50 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 1 of Set 7 | laguna
# Processing Record 2 of Set 7 | gunnedah
# Processing Record 3 of Set 7 | codrington
# Processing Record 4 of Set 7 | kargasok
# Processing Record 5 of Set 7 | marsh harbour
# Processing Record 6 of Set 7 | mehamn
# Processing Record 7 of Set 7 | noumea
# Processing Record 8 of Set 7 | madera
# Processing Record 9 of Set 7 | port hardy
# Processing Record 10 of Set 7 | seydisehir
# Processing Record 11 of Set 7 | juneau
# Processing Record 12 of Set 7 | kilosa
# Processing Record 13 of Set 7 | svetlogorsk
# Processing Record 14 of Set 7 | te anau
# Processing Record 15 of Set 7 | udachnyy
# Processing Record 16 of Set 7 | ixhuatan
# Processing Record 17 of Set 7 | marawi
# Processing Record 18 of Set 7 | taltal
# Processing Record 19 of Set 7 | kruisfontein
# Processing Record 20 of Set 7 | guerrero negro
# Processing Record 21 of Set 7 | port lincoln
# Processing Record 22 of Set 7 | kempele
# Processing Record 23 of Set 7 | cochrane
# Processing Record 24 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 25 of Set 7 | dudinka
# Processing Record 26 of Set 7 | griffith
# Processing Record 27 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 28 of Set 7 | nelson bay
# Processing Record 29 of Set 7 | bandarbeyla
# Processing Record 30 of Set 7 | bac lieu
# Processing Record 31 of Set 7 | pisco
# Processing Record 32 of Set 7 | bukachacha
# Processing Record 33 of Set 7 | tevaitoa
# Processing Record 34 of Set 7 | hervey bay
# Processing Record 35 of Set 7 | ankang
# Processing Record 36 of Set 7 | norman wells
# Processing Record 37 of Set 7 | maceio
# Processing Record 38 of Set 7 | sao marcos
# Processing Record 39 of Set 7 | olafsvik
# Processing Record 40 of Set 7 | soe
# Processing Record 41 of Set 7 | georgetown
# Processing Record 42 of Set 7 | margate
# Processing Record 43 of Set 7 | kaufbeuren
# Processing Record 44 of Set 7 | poirino
# Processing Record 45 of Set 7 | rio grande
# Processing Record 46 of Set 7 | qena
# Processing Record 47 of Set 7 | skibbereen
# Processing Record 48 of Set 7 | lagoa
# Processing Record 49 of Set 7 | inhuma
# Processing Record 50 of Set 7 | pareora
# Processing Record 1 of Set 8 | rognedino
# Processing Record 2 of Set 8 | saldanha
# Processing Record 3 of Set 8 | zhangye
# Processing Record 4 of Set 8 | ushtobe
# Processing Record 5 of Set 8 | karratha
# Processing Record 6 of Set 8 | aitape
# Processing Record 7 of Set 8 | hualmay
# Processing Record 8 of Set 8 | olinda
# Processing Record 9 of Set 8 | almaznyy
# Processing Record 10 of Set 8 | sistranda
# Processing Record 11 of Set 8 | masumbwe
# Processing Record 12 of Set 8 | san cristobal
# Processing Record 13 of Set 8 | tiassale
# Processing Record 14 of Set 8 | vardo
# Processing Record 15 of Set 8 | valleyview
# Processing Record 16 of Set 8 | necochea
# Processing Record 17 of Set 8 | mandalgovi
# Processing Record 18 of Set 8 | bengkulu
# Processing Record 19 of Set 8 | chai badan
# Processing Record 20 of Set 8 | ha
# City not found. Skipping...
# Processing Record 21 of Set 8 | bandiagara
# Processing Record 22 of Set 8 | shulan
# Processing Record 23 of Set 8 | vaitape
# Processing Record 24 of Set 8 | seattle
# Processing Record 25 of Set 8 | aktau
# Processing Record 26 of Set 8 | dasoguz
# Processing Record 27 of Set 8 | lompoc
# Processing Record 28 of Set 8 | gizo
# Processing Record 29 of Set 8 | bilibino
# Processing Record 30 of Set 8 | alice springs
# Processing Record 31 of Set 8 | businga
# Processing Record 32 of Set 8 | umm jarr
# City not found. Skipping...
# Processing Record 33 of Set 8 | keita
# Processing Record 34 of Set 8 | krasnoselkup
# Processing Record 35 of Set 8 | cedar city
# Processing Record 36 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 8 | plettenberg bay
# Processing Record 38 of Set 8 | meadow lake
# Processing Record 39 of Set 8 | zbarazh
# Processing Record 40 of Set 8 | iralaya
# Processing Record 41 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 8 | shaunavon
# Processing Record 43 of Set 8 | vila velha
# Processing Record 44 of Set 8 | ambon
# Processing Record 45 of Set 8 | abu dhabi
# Processing Record 46 of Set 8 | tezu
# Processing Record 47 of Set 8 | mattawa
# Processing Record 48 of Set 8 | tuatapere
# Processing Record 49 of Set 8 | batagay
# Processing Record 50 of Set 8 | tomari
# Processing Record 1 of Set 9 | vasai
# Processing Record 2 of Set 9 | yarada
# Processing Record 3 of Set 9 | leshukonskoye
# Processing Record 4 of Set 9 | nhulunbuy
# Processing Record 5 of Set 9 | elat
# Processing Record 6 of Set 9 | mena
# Processing Record 7 of Set 9 | poro
# Processing Record 8 of Set 9 | izvestkovyy
# Processing Record 9 of Set 9 | kamenka
# Processing Record 10 of Set 9 | key west
# Processing Record 11 of Set 9 | ndele
# Processing Record 12 of Set 9 | anjiang
# Processing Record 13 of Set 9 | sao joao da barra
# Processing Record 14 of Set 9 | rudbar
# Processing Record 15 of Set 9 | meulaboh
# Processing Record 16 of Set 9 | nagato
# Processing Record 17 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 18 of Set 9 | mizdah
# Processing Record 19 of Set 9 | lithgow
# Processing Record 20 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 21 of Set 9 | sangar
# Processing Record 22 of Set 9 | broome
# Processing Record 23 of Set 9 | omsukchan
# Processing Record 24 of Set 9 | bilma
# Processing Record 25 of Set 9 | luzhou
# Processing Record 26 of Set 9 | bandar-e lengeh
# Processing Record 27 of Set 9 | dolzhanskaya
# Processing Record 28 of Set 9 | xingyi
# Processing Record 29 of Set 9 | college
# Processing Record 30 of Set 9 | caxito
# Processing Record 31 of Set 9 | myatlevo
# Processing Record 32 of Set 9 | dingzhou
# Processing Record 33 of Set 9 | iganga
# Processing Record 34 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 9 | okha
# Processing Record 36 of Set 9 | tommot
# Processing Record 37 of Set 9 | tautira
# Processing Record 38 of Set 9 | labuhan
# Processing Record 39 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 40 of Set 9 | tecoanapa
# Processing Record 41 of Set 9 | coyuca
# City not found. Skipping...
# Processing Record 42 of Set 9 | price
# Processing Record 43 of Set 9 | caravelas
# Processing Record 44 of Set 9 | lake charles
# Processing Record 45 of Set 9 | benguela
# Processing Record 46 of Set 9 | jian
# Processing Record 47 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 9 | centralia
# Processing Record 49 of Set 9 | eshowe
# Processing Record 50 of Set 9 | luderitz
# Processing Record 1 of Set 10 | kupang
# Processing Record 2 of Set 10 | gorin
# Processing Record 3 of Set 10 | korem
# Processing Record 4 of Set 10 | oktyabrskoye
# Processing Record 5 of Set 10 | westport
# Processing Record 6 of Set 10 | japoata
# Processing Record 7 of Set 10 | zvishavane
# Processing Record 8 of Set 10 | ratnagiri
# Processing Record 9 of Set 10 | caucaia
# Processing Record 10 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 10 | okhotsk
# Processing Record 12 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 13 of Set 10 | mount isa
# Processing Record 14 of Set 10 | beeville
# Processing Record 15 of Set 10 | roebourne
# Processing Record 16 of Set 10 | wanxian
# Processing Record 17 of Set 10 | grindavik
# Processing Record 18 of Set 10 | airai
# Processing Record 19 of Set 10 | lucapa
# Processing Record 20 of Set 10 | guilin
# Processing Record 21 of Set 10 | klaksvik
# Processing Record 22 of Set 10 | asau
# Processing Record 23 of Set 10 | antofagasta
# Processing Record 24 of Set 10 | alberton
# Processing Record 25 of Set 10 | ovre ardal
# Processing Record 26 of Set 10 | durazno
# Processing Record 27 of Set 10 | kyra
# Processing Record 28 of Set 10 | adrar
# Processing Record 29 of Set 10 | qingdao
# Processing Record 30 of Set 10 | stephenville
# Processing Record 31 of Set 10 | ormond beach
# Processing Record 32 of Set 10 | ostrovnoy
# Processing Record 33 of Set 10 | aklavik
# Processing Record 34 of Set 10 | masallatah
# Processing Record 35 of Set 10 | hofn
# Processing Record 36 of Set 10 | ewa beach
# Processing Record 37 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 10 | chikwawa
# Processing Record 39 of Set 10 | ca mau
# Processing Record 40 of Set 10 | neath
# Processing Record 41 of Set 10 | qandala
# Processing Record 42 of Set 10 | novyy urengoy
# Processing Record 43 of Set 10 | saryagash
# Processing Record 44 of Set 10 | nianzishan
# Processing Record 45 of Set 10 | chapada dos guimaraes
# Processing Record 46 of Set 10 | ivdel
# Processing Record 47 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 10 | poquoson
# Processing Record 49 of Set 10 | srandakan
# Processing Record 50 of Set 10 | sandovo
# Processing Record 1 of Set 11 | zyryanka
# Processing Record 2 of Set 11 | berlevag
# Processing Record 3 of Set 11 | beloha
# Processing Record 4 of Set 11 | hovd
# Processing Record 5 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 11 | makokou
# Processing Record 7 of Set 11 | asfi
# Processing Record 8 of Set 11 | clyde river
# Processing Record 9 of Set 11 | burica
# City not found. Skipping...
# Processing Record 10 of Set 11 | tungawan
# Processing Record 11 of Set 11 | gulariya
# Processing Record 12 of Set 11 | algiers
# Processing Record 13 of Set 11 | mazara del vallo
# Processing Record 14 of Set 11 | krasnyy yar
# Processing Record 15 of Set 11 | bani
# Processing Record 16 of Set 11 | havelock
# Processing Record 17 of Set 11 | vestmannaeyjar
# Processing Record 18 of Set 11 | bastrop
# Processing Record 19 of Set 11 | baoying
# Processing Record 20 of Set 11 | tahe
# Processing Record 21 of Set 11 | general pico
# Processing Record 22 of Set 11 | urumqi
# Processing Record 23 of Set 11 | los llanos de aridane
# Processing Record 24 of Set 11 | afmadu
# City not found. Skipping...
# Processing Record 25 of Set 11 | buta
# Processing Record 26 of Set 11 | nkhata bay
# Processing Record 27 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 28 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 11 | tchollire
# Processing Record 30 of Set 11 | abbeville
# Processing Record 31 of Set 11 | kilindoni
# Processing Record 32 of Set 11 | ayan
# Processing Record 33 of Set 11 | xai-xai
# Processing Record 34 of Set 11 | lakhimpur
# Processing Record 35 of Set 11 | mount gambier
# Processing Record 36 of Set 11 | nishihara
# Processing Record 37 of Set 11 | trzebiatow
# Processing Record 38 of Set 11 | sigli
# Processing Record 39 of Set 11 | vagay
# Processing Record 40 of Set 11 | jefferson city
# Processing Record 41 of Set 11 | sterling
# Processing Record 42 of Set 11 | tema
# Processing Record 43 of Set 11 | omboue
# Processing Record 44 of Set 11 | mbandaka
# Processing Record 45 of Set 11 | ornskoldsvik
# Processing Record 46 of Set 11 | wamba
# Processing Record 47 of Set 11 | bolgatanga
# Processing Record 48 of Set 11 | nouadhibou
# Processing Record 49 of Set 11 | xining
# Processing Record 50 of Set 11 | akdepe
# Processing Record 1 of Set 12 | walvis bay
# Processing Record 2 of Set 12 | carroll
# Processing Record 3 of Set 12 | pyaozerskiy
# Processing Record 4 of Set 12 | port-cartier
# Processing Record 5 of Set 12 | mitsamiouli
# Processing Record 6 of Set 12 | cayenne
# Processing Record 7 of Set 12 | luanda
# Processing Record 8 of Set 12 | glendive
# Processing Record 9 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 10 of Set 12 | california city
# Processing Record 11 of Set 12 | faya
# Processing Record 12 of Set 12 | slonim
# Processing Record 13 of Set 12 | ozark
# Processing Record 14 of Set 12 | tual
# Processing Record 15 of Set 12 | mahanoro
# Processing Record 16 of Set 12 | dryden
# Processing Record 17 of Set 12 | beian
# Processing Record 18 of Set 12 | mahibadhoo
# Processing Record 19 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 12 | basco
# Processing Record 21 of Set 12 | xinqing
# Processing Record 22 of Set 12 | brownsville
# Processing Record 23 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 12 | brae
# Processing Record 25 of Set 12 | uvat
# Processing Record 26 of Set 12 | pyatnitskoye
# Processing Record 27 of Set 12 | herat
# Processing Record 28 of Set 12 | aksarka
# Processing Record 29 of Set 12 | kalmunai
# Processing Record 30 of Set 12 | maniitsoq
# Processing Record 31 of Set 12 | yekaterinoslavka
# Processing Record 32 of Set 12 | praia
# Processing Record 33 of Set 12 | dingle
# Processing Record 34 of Set 12 | sabha
# Processing Record 35 of Set 12 | gerash
# Processing Record 36 of Set 12 | goba
# Processing Record 37 of Set 12 | bafra
# Processing Record 38 of Set 12 | beringovskiy
# Processing Record 39 of Set 12 | padang
# Processing Record 40 of Set 12 | waycross
# Processing Record 41 of Set 12 | payson
# Processing Record 42 of Set 12 | korla
# Processing Record 43 of Set 12 | qui nhon
# Processing Record 44 of Set 12 | inongo
# Processing Record 45 of Set 12 | samarkand
# Processing Record 46 of Set 12 | ixtapa
# Processing Record 47 of Set 12 | chapais
# Processing Record 48 of Set 12 | nara
# Processing Record 49 of Set 12 | grand gaube
# Processing Record 50 of Set 12 | monzon
# Processing Record 1 of Set 13 | port blair
# Processing Record 2 of Set 13 | novyy urgal
# Processing Record 3 of Set 13 | karasjok
# Processing Record 4 of Set 13 | vestmanna
# Processing Record 5 of Set 13 | kumburgaz
# Processing Record 6 of Set 13 | belaya gora
# Processing Record 7 of Set 13 | kautokeino
# Processing Record 8 of Set 13 | along
# Processing Record 9 of Set 13 | oranjestad
# Processing Record 10 of Set 13 | santa rosa
# Processing Record 11 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 12 of Set 13 | lishui
# Processing Record 13 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 13 | saint-georges
# Processing Record 15 of Set 13 | thinadhoo
# Processing Record 16 of Set 13 | cromarty
# Processing Record 17 of Set 13 | yenagoa
# Processing Record 18 of Set 13 | atikokan
# Processing Record 19 of Set 13 | port macquarie
# Processing Record 20 of Set 13 | khetia
# Processing Record 21 of Set 13 | taoudenni
# Processing Record 22 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 23 of Set 13 | gat
# Processing Record 24 of Set 13 | lostice
# Processing Record 25 of Set 13 | narasannapeta
# Processing Record 26 of Set 13 | tabora
# Processing Record 27 of Set 13 | saint anthony
# Processing Record 28 of Set 13 | chor
# Processing Record 29 of Set 13 | mackay
# Processing Record 30 of Set 13 | konin
# Processing Record 31 of Set 13 | muscat
# Processing Record 32 of Set 13 | krasnyy chikoy
# Processing Record 33 of Set 13 | chicama
# Processing Record 34 of Set 13 | kismayo
# Processing Record 35 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 13 | kurilsk
# Processing Record 37 of Set 13 | villazon
# Processing Record 38 of Set 13 | turukhansk
# Processing Record 39 of Set 13 | havoysund
# Processing Record 40 of Set 13 | rabaul
# Processing Record 41 of Set 13 | salinopolis
# Processing Record 42 of Set 13 | puerto carreno
# Processing Record 43 of Set 13 | jalapa
# Processing Record 44 of Set 13 | chibuto
# Processing Record 45 of Set 13 | cao bang
# Processing Record 46 of Set 13 | ilhabela
# Processing Record 47 of Set 13 | buraydah
# Processing Record 48 of Set 13 | sao domingos
# Processing Record 49 of Set 13 | mirnyy
# Processing Record 50 of Set 13 | mineral wells
# Processing Record 1 of Set 14 | itoman
# Processing Record 2 of Set 14 | nova venecia
# Processing Record 3 of Set 14 | sao jose da coroa grande
# Processing Record 4 of Set 14 | kapit
# Processing Record 5 of Set 14 | gunjur
# Processing Record 6 of Set 14 | morgan city
# Processing Record 7 of Set 14 | frankfort
# Processing Record 8 of Set 14 | pulandian
# Processing Record 9 of Set 14 | liverpool
# Processing Record 10 of Set 14 | keti bandar
# Processing Record 11 of Set 14 | sorong
# Processing Record 12 of Set 14 | itiuba
# Processing Record 13 of Set 14 | sobolevo
# Processing Record 14 of Set 14 | poum
# Processing Record 15 of Set 14 | saint-philippe
# Processing Record 16 of Set 14 | turmero
# Processing Record 17 of Set 14 | comarapa
# Processing Record 18 of Set 14 | san juan
# Processing Record 19 of Set 14 | kulevcha
# Processing Record 20 of Set 14 | kenai
# Processing Record 21 of Set 14 | itarema
# Processing Record 22 of Set 14 | leh
# Processing Record 23 of Set 14 | gangarampur
# Processing Record 24 of Set 14 | makungu
# Processing Record 25 of Set 14 | wajid
# Processing Record 26 of Set 14 | rehoboth
# Processing Record 27 of Set 14 | peterhead
# Processing Record 28 of Set 14 | concordia
# Processing Record 29 of Set 14 | beni mazar
# Processing Record 30 of Set 14 | lusambo
# Processing Record 31 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 14 | tocantinopolis
# City not found. Skipping...
# Processing Record 33 of Set 14 | agua branca
# Processing Record 34 of Set 14 | kosh-agach
# Processing Record 35 of Set 14 | ilulissat
# Processing Record 36 of Set 14 | aksu
# Processing Record 37 of Set 14 | bobrovytsya
# Processing Record 38 of Set 14 | dongsheng
# Processing Record 39 of Set 14 | sovetskiy
# Processing Record 40 of Set 14 | bizhbulyak
# Processing Record 41 of Set 14 | pocone
# Processing Record 42 of Set 14 | san ramon
# Processing Record 43 of Set 14 | twin falls
# Processing Record 44 of Set 14 | segou
# Processing Record 45 of Set 14 | alexandria
# Processing Record 46 of Set 14 | pokhara
# Processing Record 47 of Set 14 | slave lake
# Processing Record 48 of Set 14 | verkhoyansk
# Processing Record 49 of Set 14 | sinnamary
# Processing Record 50 of Set 14 | khobi
# Processing Record 1 of Set 15 | paamiut
# Processing Record 2 of Set 15 | hella
# Processing Record 3 of Set 15 | orlik
# Processing Record 4 of Set 15 | sawakin
# Processing Record 5 of Set 15 | truro
# Processing Record 6 of Set 15 | rosario
# Processing Record 7 of Set 15 | makushino
# Processing Record 8 of Set 15 | rawson
# Processing Record 9 of Set 15 | manokwari
# Processing Record 10 of Set 15 | kambove
# Processing Record 11 of Set 15 | chapleau
# Processing Record 12 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 13 of Set 15 | kloulklubed
# Processing Record 14 of Set 15 | thyboron
# Processing Record 15 of Set 15 | shenjiamen
# Processing Record 16 of Set 15 | ugoofaaru
# Processing Record 17 of Set 15 | bairnsdale
# Processing Record 18 of Set 15 | alamosa
# Processing Record 19 of Set 15 | arkhangelsk
# Processing Record 20 of Set 15 | havre-saint-pierre
# Processing Record 21 of Set 15 | dothan
# Processing Record 22 of Set 15 | tazmalt
# Processing Record 23 of Set 15 | vao
# Processing Record 24 of Set 15 | camacha
# Processing Record 25 of Set 15 | chernyshevskiy
# Processing Record 26 of Set 15 | samarai
# Processing Record 27 of Set 15 | aztec
# Processing Record 28 of Set 15 | japura
# Processing Record 29 of Set 15 | camana
# Processing Record 30 of Set 15 | houlton
# Processing Record 31 of Set 15 | lulea
# Processing Record 32 of Set 15 | hobyo
# Processing Record 33 of Set 15 | port shepstone
# Processing Record 34 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 35 of Set 15 | smithers
# Processing Record 36 of Set 15 | harper
# Processing Record 37 of Set 15 | belyy yar
# Processing Record 38 of Set 15 | williston
# Processing Record 39 of Set 15 | lakatoro
# Processing Record 40 of Set 15 | mendoza
# Processing Record 41 of Set 15 | bogorodskoye
# Processing Record 42 of Set 15 | udalguri
# Processing Record 43 of Set 15 | irbeyskoye
# Processing Record 44 of Set 15 | ileza
# Processing Record 45 of Set 15 | oktyabrskiy
# Processing Record 46 of Set 15 | santiago de chuco
# Processing Record 47 of Set 15 | baghdad
# Processing Record 48 of Set 15 | groningen
# Processing Record 49 of Set 15 | ivanivka
# Processing Record 50 of Set 15 | ha tinh
# Processing Record 1 of Set 16 | lasa
# Processing Record 2 of Set 16 | berdyaush
# Processing Record 3 of Set 16 | baykit
# Processing Record 4 of Set 16 | hrymayliv
# Processing Record 5 of Set 16 | sorland
# Processing Record 6 of Set 16 | tres arroyos
# Processing Record 7 of Set 16 | alihe
# --------------------
# Data Retrieval Complete
# --------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp Current Description  \
# 0   tuktoyaktuk  69.4541 -133.0374     46.40          light rain
# 1  punta arenas -53.1500  -70.9167     39.31       moderate rain
# 2       douglas  41.3000  -96.1670     68.88       broken clouds
# 3     busselton -33.6500  115.3333     62.60          few clouds
# 4       ushuaia -54.8000  -68.3000     44.26     overcast clouds
# 5  constitucion -35.3333  -72.4167     51.94           clear sky
# 6      souillac -20.5167   57.5167     71.98    scattered clouds
# 7       sechura  -5.5569  -80.8222     67.03       broken clouds
# 8  saint george  37.1041 -113.5841     74.95           clear sky
# 9         alofi -19.0595 -169.9187     73.29       broken clouds
#
#    Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0           0.00              0        87         100       10.36      CA
# 1           1.16              0        87          75       17.27      CL
# 2           0.00              0        79          75        9.22      US
# 3           0.00              0        82          18       16.60      AU
# 4           0.00              0        65         100       10.36      AR
# 5           0.00              0        67           0        7.63      CL
# 6           0.00              0        73          40       10.36      MU
# 7           0.00              0        73          56       12.03      PE
# 8           0.00              0        83           0        4.61      US
# 9           0.00              0        83          81       12.66      NU

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
